# %% [markdown]
# ## Task 1: Virtual Machine vs. Container Resource Footprint Analysis
#
# Compare the architecture of a hardware-based hypervisor (Type 1) running three virtual machines with an operating system-level containerization engine (such as Docker) running three application containers on the same physical host.
#
# Answer the following questions:
#
# 1. How does guest OS isolation differ between VMs and containers?
# 2. Why do containers exhibit a smaller storage and memory footprint compared to VMs?
# 3. In what deployment scenarios would you still choose a virtual machine over a container?

# %% [markdown]
# ## Task 2: Data Center Network Subsystem Mapping
#
# Review the five data center network subsystems covered in Chapter 5 (Carrier/External Interconnection, Web-Tier Load Balancing/Acceleration, LAN Fabric, SAN Fabric, and NAS Gateways).
#
# Map each subsystem to its primary hardware components and describe how redundancy and high availability are achieved across these layers to prevent data center outages.
