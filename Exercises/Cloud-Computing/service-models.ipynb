# %% [markdown]
# ## Cloud Service Models

# %% [markdown]
# ### Exercise 1: Selecting Cloud Service Models for a University System
# A university needs an online system that allows students to register for courses. The system includes:
# - A public registration website
# - A database containing student and course information
# - Automatic confirmation emails
# - File storage for course documents
# - Staff email and document collaboration
#
# For each component, select IaaS, PaaS, FaaS, or SaaS.
# Explain your choice by considering:
# - The level of control required
# - The technical work managed by the provider
# - The responsibilities remaining with the university
# - Scalability during busy registration periods
# - Security and data-protection requirements
#
# Create a table containing the component, selected service model, customer responsibilities, provider responsibilities, and justification. Finish with a simple architecture diagram showing how the components interact.

# %% [markdown]
# ## Exercise 2: Creating and Testing an Event-Driven Function
# Using the instructor-provided cloud sandbox or FaaS environment, create a small function that receives a student’s name and course title and returns a registration confirmation message.
#
#
# Example input:

# %%
# JSON
{
  "student": "Sara",
  "course": "Cloud Computing"
}

# %% [markdown]
# Expected output:

# %%
# JSON
{
  "message": "Sara has registered for Cloud Computing."
}

# %% [markdown]
# Complete the following steps:
# 1. Create the function using a supported programming language.
# 2. Configure an HTTP request or test event as the trigger.
# 3. Execute the function with at least three different inputs.
# 4. Test one invalid input, such as a missing course title.
# 5. Review the execution logs and identify the execution time and result.
# 6. Modify the function to return a clear error message for invalid input.
#
#
# Submit the function code, screenshots of successful and unsuccessful tests, and a short explanation of the trigger, input, output, scaling responsibility, and tasks managed by the cloud provider.
